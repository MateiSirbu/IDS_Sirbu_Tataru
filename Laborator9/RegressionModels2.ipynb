# %%
import numpy as np
import pandas as pd

from IPython.display import display, HTML
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate,cross_val_score, train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold


import sklearn
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.linear_model import Lasso, BayesianRidge, ElasticNet
from sklearn import linear_model
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from scipy.stats import uniform as sp_rand
import scipy.stats as stats

# %% [markdown]
# # Load data set

# %%
heads=[
'Lymph_node',
'radius_mean',
'texture_mean',
'perimeter_mean',
'area_mean',
'smoothness_mean',
'compactness_mean',
'concavity_mean',
'concave_points_mean',
'symmetry_mean',
'fractal_dimension_mean',
'radius_se',
'texture_se',
'perimeter_se',
'area_se',
'smoothness_se',
'compactness_se',
'concavity_se',
'concave_points_se',
'symmetry_se',
'fractal_dimension_se',
'radius_worst',
'texture_worst',
'perimeter_worst',
'area_worst',
'smoothness_worst',
'compactness_worst',
'concavity_worst',
'concave_points_worst',
'symmetry_worst',
'fractal_dimension_worst',
'Tumor_size',
'Time',
]

#Replacing missing data types with NAN
missingValues = ["n/a", "na", "--"," ","?"]
data_wisconsin = pd.read_csv("./Datasets/r_wpbc.data",sep=',',names=heads,na_values=missingValues)

display(data_wisconsin)
# Out:
#      Lymph_node  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0             5        18.02         27.60          117.50     1013.0
# 1             2        17.99         10.38          122.80     1001.0
# 2             0        21.37         17.44          137.50     1373.0
# 3             0        11.42         20.38           77.58      386.1
# 4             0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 189          21        14.72         25.26           99.28      657.5
# 190           2        22.52         21.92          146.90     1597.0
# 191           0        15.44         31.18          101.00      740.4
# 192           0        17.17         29.19          110.00      915.3
# 193           0        16.70         28.13          110.30      885.4
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0            0.09489           0.10360         0.10860              0.07055
# 1            0.11840           0.27760         0.30010              0.14710
# 2            0.08836           0.11890         0.12550              0.08180
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 189          0.11740           0.21120         0.17290              0.09465
# 190          0.07592           0.09162         0.06862              0.06367
# 191          0.09399           0.10620         0.13750              0.06500
# 192          0.08952           0.06655         0.06583              0.05068
# 193          0.08896           0.11310         0.10120              0.04989
#
#      symmetry_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# 0           0.1865  ...           139.70      1436.0           0.11950
# 1           0.2419  ...           184.60      2019.0           0.16220
# 2           0.2333  ...           159.10      1949.0           0.11880
# 3           0.2597  ...            98.87       567.7           0.20980
# 4           0.1809  ...           152.20      1575.0           0.13740
# ..             ...  ...              ...         ...               ...
# 189         0.2079  ...           111.60       814.8           0.14640
# 190         0.1728  ...           162.10      1902.0           0.08191
# 191         0.1735  ...           112.60       929.0           0.12720
# 192         0.1793  ...           132.50      1295.0           0.12610
# 193         0.1890  ...           128.80      1213.0           0.13300
#
#      compactness_worst  concavity_worst  concave_points_worst  symmetry_worst  \
# 0               0.1926           0.3140               0.11700          0.2677
# 1               0.6656           0.7119               0.26540          0.4601
# 2               0.3449           0.3414               0.20320          0.4334
# 3               0.8663           0.6869               0.25750          0.6638
# 4               0.2050           0.4000               0.16250          0.2364
# ..                 ...              ...                   ...             ...
# 189             0.5352           0.5655               0.19740          0.3778
# 190             0.1319           0.1056               0.09378          0.2061
# 191             0.2362           0.2975               0.12860          0.2914
# 192             0.1572           0.2141               0.09520          0.3362
# 193             0.2808           0.3455               0.13170          0.3035
#
#      fractal_dimension_worst  Tumor_size  Time
# 0                    0.08113         5.0    31
# 1                    0.11890         3.0    61
# 2                    0.09067         2.5   116
# 3                    0.17300         2.0   123
# 4                    0.07678         3.5    27
# ..                       ...         ...   ...
# 189                  0.11320         1.7     3
# 190                  0.05788         6.0    10
# 191                  0.08024         1.5     8
# 192                  0.06033         3.7    12
# 193                  0.08036         3.5     6
#
# [194 rows x 33 columns]

# %% [markdown]
# # Checking for missing data

# %%
display(data_wisconsin.info())

#Afisam numarul de missind data in functie de coloana
df=pd.DataFrame(data_wisconsin.isnull().sum())

#pentru a putea afisa toate coloanele nu doar limita pd
with pd.option_context('display.max_rows', None):display(df)

#Afisam numarul de missind data in total
print (data_wisconsin.isnull().sum().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Lymph_node               194 non-null    int64
#  1   radius_mean              194 non-null    float64
#  2   texture_mean             194 non-null    float64
#  3   perimeter_mean           194 non-null    float64
#  4   area_mean                194 non-null    float64
#  5   smoothness_mean          194 non-null    float64
#  6   compactness_mean         194 non-null    float64
#  7   concavity_mean           194 non-null    float64
#  8   concave_points_mean      194 non-null    float64
#  9   symmetry_mean            194 non-null    float64
#  10  fractal_dimension_mean   194 non-null    float64
#  11  radius_se                194 non-null    float64
#  12  texture_se               194 non-null    float64
#  13  perimeter_se             194 non-null    float64
#  14  area_se                  194 non-null    float64
#  15  smoothness_se            194 non-null    float64
#  16  compactness_se           194 non-null    float64
#  17  concavity_se             194 non-null    float64
#  18  concave_points_se        194 non-null    float64
#  19  symmetry_se              194 non-null    float64
#  20  fractal_dimension_se     194 non-null    float64
#  21  radius_worst             194 non-null    float64
#  22  texture_worst            194 non-null    float64
#  23  perimeter_worst          194 non-null    float64
#  24  area_worst               194 non-null    float64
#  25  smoothness_worst         194 non-null    float64
#  26  compactness_worst        194 non-null    float64
#  27  concavity_worst          194 non-null    float64
#  28  concave_points_worst     194 non-null    float64
#  29  symmetry_worst           194 non-null    float64
#  30  fractal_dimension_worst  194 non-null    float64
#  31  Tumor_size               194 non-null    float64
#  32  Time                     194 non-null    int64
# dtypes: float64(31), int64(2)
# memory usage: 50.1 KB
# None
#                          0
# Lymph_node               0
# radius_mean              0
# texture_mean             0
# perimeter_mean           0
# area_mean                0
# smoothness_mean          0
# compactness_mean         0
# concavity_mean           0
# concave_points_mean      0
# symmetry_mean            0
# fractal_dimension_mean   0
# radius_se                0
# texture_se               0
# perimeter_se             0
# area_se                  0
# smoothness_se            0
# compactness_se           0
# concavity_se             0
# concave_points_se        0
# symmetry_se              0
# fractal_dimension_se     0
# radius_worst             0
# texture_worst            0
# perimeter_worst          0
# area_worst               0
# smoothness_worst         0
# compactness_worst        0
# concavity_worst          0
# concave_points_worst     0
# symmetry_worst           0
# fractal_dimension_worst  0
# Tumor_size               0
# Time                     0
# 0

# %% [markdown]
# # Split DataSet

# %%
newHead=data_wisconsin.columns

X = data_wisconsin.values[:, :32]
X = pd.DataFrame(X, columns=newHead[0:32])
y = data_wisconsin.values[:, -1]
y = pd.DataFrame(y, columns=['Time'])

display(X)
display(y)
# Out:
#      Lymph_node  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           5.0        18.02         27.60          117.50     1013.0
# 1           2.0        17.99         10.38          122.80     1001.0
# 2           0.0        21.37         17.44          137.50     1373.0
# 3           0.0        11.42         20.38           77.58      386.1
# 4           0.0        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 189        21.0        14.72         25.26           99.28      657.5
# 190         2.0        22.52         21.92          146.90     1597.0
# 191         0.0        15.44         31.18          101.00      740.4
# 192         0.0        17.17         29.19          110.00      915.3
# 193         0.0        16.70         28.13          110.30      885.4
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0            0.09489           0.10360         0.10860              0.07055
# 1            0.11840           0.27760         0.30010              0.14710
# 2            0.08836           0.11890         0.12550              0.08180
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 189          0.11740           0.21120         0.17290              0.09465
# 190          0.07592           0.09162         0.06862              0.06367
# 191          0.09399           0.10620         0.13750              0.06500
# 192          0.08952           0.06655         0.06583              0.05068
# 193          0.08896           0.11310         0.10120              0.04989
#
#      symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0           0.1865  ...          37.08           139.70      1436.0
# 1           0.2419  ...          17.33           184.60      2019.0
# 2           0.2333  ...          20.98           159.10      1949.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 189         0.2079  ...          31.97           111.60       814.8
# 190         0.1728  ...          24.81           162.10      1902.0
# 191         0.1735  ...          41.48           112.60       929.0
# 192         0.1793  ...          36.66           132.50      1295.0
# 193         0.1890  ...          34.92           128.80      1213.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.11950             0.1926           0.3140
# 1             0.16220             0.6656           0.7119
# 2             0.11880             0.3449           0.3414
# 3             0.20980             0.8663           0.6869
# 4             0.13740             0.2050           0.4000
# ..                ...                ...              ...
# 189           0.14640             0.5352           0.5655
# 190           0.08191             0.1319           0.1056
# 191           0.12720             0.2362           0.2975
# 192           0.12610             0.1572           0.2141
# 193           0.13300             0.2808           0.3455
#
#      concave_points_worst  symmetry_worst  fractal_dimension_worst  Tumor_size
# 0                 0.11700          0.2677                  0.08113         5.0
# 1                 0.26540          0.4601                  0.11890         3.0
# 2                 0.20320          0.4334                  0.09067         2.5
# 3                 0.25750          0.6638                  0.17300         2.0
# 4                 0.16250          0.2364                  0.07678         3.5
# ..                    ...             ...                      ...         ...
# 189               0.19740          0.3778                  0.11320         1.7
# 190               0.09378          0.2061                  0.05788         6.0
# 191               0.12860          0.2914                  0.08024         1.5
# 192               0.09520          0.3362                  0.06033         3.7
# 193               0.13170          0.3035                  0.08036         3.5
#
# [194 rows x 32 columns]
#       Time
# 0     31.0
# 1     61.0
# 2    116.0
# 3    123.0
# 4     27.0
# ..     ...
# 189    3.0
# 190   10.0
# 191    8.0
# 192   12.0
# 193    6.0
#
# [194 rows x 1 columns]

# %% [markdown]
# # Lasso Regression

# %%
pipe = Pipeline([('lss', Lasso(max_iter=50000,))])

parameter_grid = { 'lss__alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float)}
k_fold = KFold(n_splits=5, shuffle=True)
grid_search =RandomizedSearchCV(estimator=pipe, param_distributions=parameter_grid,cv=KFold(3), n_iter=100)
scores = cross_validate(grid_search, X, y, cv=k_fold,scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True )
print("Scorurile rezultate in urma 5-fold cross validation")
pd_scores_lasso = pd.DataFrame(scores)

pd_scores_lasso.insert(0, "ModelName", ['Lasso_1', 'Lasso_2','Lasso_3', 'Lasso_4','Lasso_5']) 
display(pd_scores_lasso)
# Out:
# Scorurile rezultate in urma 5-fold cross validation
#   ModelName  fit_time  score_time  test_neg_mean_absolute_error  \
# 0   Lasso_1  6.098969    0.004492                    -22.492861
# 1   Lasso_2  7.544734    0.003992                    -28.110288
# 2   Lasso_3  6.200274    0.004492                    -31.142568
# 3   Lasso_4  7.329637    0.003993                    -23.697818
# 4   Lasso_5  6.353981    0.003994                    -30.422749
#
#    train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -26.542915                  -804.591877
# 1                     -25.292629                 -1004.984452
# 2                     -24.295932                 -1339.784033
# 3                     -25.206253                  -900.301867
# 4                     -24.399795                 -1286.935592
#
#    train_neg_mean_squared_error  test_neg_median_absolute_error  \
# 0                   -985.898650                      -19.035597
# 1                   -947.172683                      -27.361920
# 2                   -861.365320                      -28.577077
# 3                   -917.430209                      -18.798960
# 4                   -872.723226                      -28.128453
#
#    train_neg_median_absolute_error
# 0                       -23.695251
# 1                       -22.776798
# 2                       -21.748190
# 3                       -23.810124
# 4                       -20.829830

# %% [markdown]
# # Ridge Regression

# %%
pipe = Pipeline([('rid', linear_model.Ridge())])
parameter_grid = { 'rid__alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float)}
k_fold = KFold(n_splits=5, shuffle=True)
grid_search =RandomizedSearchCV(estimator=pipe, param_distributions=parameter_grid,cv=KFold(3), n_iter=100)
scores = cross_validate(grid_search, X, y, cv=k_fold, scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True )
print("Scorurile rezultate in urma 5-fold cross validation")
pd_scores_ridge = pd.DataFrame(scores)

pd_scores_ridge.insert(0, "ModelName", ['Ridge_1', 'Ridge_2','Ridge_3', 'Ridge_4','Ridge_5']) 
display(pd_scores_ridge)
# Out:
# Scorurile rezultate in urma 5-fold cross validation
#   ModelName  fit_time  score_time  test_neg_mean_absolute_error  \
# 0   Ridge_1  2.664961    0.003990                    -22.521895
# 1   Ridge_2  2.613557    0.005489                    -25.614895
# 2   Ridge_3  2.631525    0.003992                    -27.867464
# 3   Ridge_4  2.614553    0.004493                    -25.225309
# 4   Ridge_5  2.581115    0.003993                    -32.629801
#
#    train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -25.829638                  -834.883272
# 1                     -24.915519                 -1046.513942
# 2                     -24.524450                 -1039.556331
# 3                     -24.615388                 -1006.130841
# 4                     -23.131360                 -1399.757328
#
#    train_neg_mean_squared_error  test_neg_median_absolute_error  \
# 0                   -946.911462                      -19.181058
# 1                   -896.880794                      -23.344430
# 2                   -897.629016                      -28.911643
# 3                   -889.932368                      -17.366068
# 4                   -810.892142                      -32.479047
#
#    train_neg_median_absolute_error
# 0                       -22.094490
# 1                       -23.288056
# 2                       -20.736889
# 3                       -22.186764
# 4                       -20.128217

# %% [markdown]
# # Elastic Net Regression

# %%
pipe = Pipeline([('enr', linear_model.ElasticNet(max_iter=50000))])

parameter_grid = { 'enr__alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float),'enr__l1_ratio':np.linspace(start=1e-5, stop=1, num=10000, dtype=float)}
k_fold = KFold(n_splits=5, shuffle=True)
grid_search =RandomizedSearchCV(estimator=pipe, param_distributions=parameter_grid,cv=KFold(3), n_iter=200)
scores = cross_validate(grid_search, X, y, cv=k_fold, scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True )
print("Scorurile rezultate in urma 5-fold cross validation")
pd_scores_net_reg = pd.DataFrame(scores)

pd_scores_net_reg.insert(0, "ModelName", ['ElasticNet_1', 'ElasticNet_2','ElasticNet_3', 'ElasticNet_4','ElasticNet_5']) 
display(pd_scores_net_reg)
# Out:
# Scorurile rezultate in urma 5-fold cross validation
#       ModelName   fit_time  score_time  test_neg_mean_absolute_error  \
# 0  ElasticNet_1  11.747275    0.003992                    -27.747970
# 1  ElasticNet_2  10.070449    0.003991                    -28.585588
# 2  ElasticNet_3   9.890287    0.003992                    -27.986716
# 3  ElasticNet_4  12.013764    0.004493                    -23.783251
# 4  ElasticNet_5  10.210176    0.004493                    -26.775535
#
#    train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -24.978662                 -1057.269636
# 1                     -24.904533                 -1104.074295
# 2                     -25.203920                 -1148.039517
# 3                     -25.645028                  -857.987641
# 4                     -25.485469                 -1074.049728
#
#    train_neg_mean_squared_error  test_neg_median_absolute_error  \
# 0                   -920.780164                      -26.505246
# 1                   -923.819535                      -25.467898
# 2                   -903.153271                      -25.844953
# 3                   -967.559262                      -22.509531
# 4                   -924.407517                      -22.997109
#
#    train_neg_median_absolute_error
# 0                       -22.293134
# 1                       -21.977245
# 2                       -21.816909
# 3                       -22.215897
# 4                       -22.000744

# %% [markdown]
# # SGD Regression

# %%
pipe = Pipeline([('scaler', StandardScaler()),('sgr', linear_model.SGDRegressor(max_iter=10000))])

parameter_grid = {
                  'sgr__loss': ['squared_loss', 'huber', 'epsilon_insensitive','squared_epsilon_insensitive'],
                  'sgr__l1_ratio':  np.linspace(start=0, stop=1),
                  'sgr__alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float)
                 }

k_fold = KFold(n_splits=5, shuffle=True)
grid_search =RandomizedSearchCV(estimator=pipe, param_distributions=parameter_grid,cv=KFold(3), n_iter=100)
scores = cross_validate(grid_search, X, y.to_numpy().ravel(), cv=k_fold, scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True )
print("Scorurile rezultate in urma 5-fold cross validation")
pd_scores_sgdr = pd.DataFrame(scores)

pd_scores_sgdr.insert(0, "ModelName", ['SGD_1', 'SGD_2','SGD_3', 'SGD_4','SGD_5']) 
display(pd_scores_sgdr)
# Out:
# Scorurile rezultate in urma 5-fold cross validation
#   ModelName  fit_time  score_time  test_neg_mean_absolute_error  \
# 0     SGD_1  4.681140    0.002995                    -27.995860
# 1     SGD_2  5.140270    0.002496                    -24.665230
# 2     SGD_3  4.514457    0.001997                    -28.239823
# 3     SGD_4  4.652191    0.002496                    -30.074858
# 4     SGD_5  4.596300    0.001997                    -29.554113
#
#    train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -27.420635                 -1201.517392
# 1                     -24.345003                  -900.216613
# 2                     -29.015965                 -1228.611385
# 3                     -23.709845                 -1383.237522
# 4                     -23.856161                 -1238.099548
#
#    train_neg_mean_squared_error  test_neg_median_absolute_error  \
# 0                  -1158.426264                      -22.465961
# 1                   -870.769352                      -24.937104
# 2                  -1310.890711                      -21.859992
# 3                   -889.652790                      -26.784360
# 4                   -816.156645                      -25.252975
#
#    train_neg_median_absolute_error
# 0                       -23.648975
# 1                       -20.484908
# 2                       -25.033691
# 3                       -20.199998
# 4                       -21.349745

# %% [markdown]
# # LassoLars Regression

# %%
pipe = Pipeline([('lar',linear_model.LassoLars())])
parameter_grid = { 'lar__alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float),
                  
                 }

k_fold = KFold(n_splits=5, shuffle=True)
grid_search =RandomizedSearchCV(estimator=pipe, param_distributions=parameter_grid,cv=KFold(3), n_iter=100)
scores = cross_validate(grid_search, X, y.to_numpy().ravel(), cv=k_fold, scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True )
print("Scorurile rezultate in urma 5-fold cross validation")
pd_scores_laso = pd.DataFrame(scores)

pd_scores_laso.insert(0, "ModelName", ['LassoLars_1', 'LassoLars_2','LassoLars_3', 'LassoLars_4','LassoLars_5']) 
display(pd_scores_laso)
# Out:
# Scorurile rezultate in urma 5-fold cross validation
#      ModelName  fit_time  score_time  test_neg_mean_absolute_error  \
# 0  LassoLars_1  2.406444    0.001996                    -30.425442
# 1  LassoLars_2  2.915481    0.001996                    -25.804088
# 2  LassoLars_3  2.510747    0.001996                    -21.556174
# 3  LassoLars_4  2.782732    0.002495                    -24.762187
# 4  LassoLars_5  2.530709    0.001996                    -29.758421
#
#    train_neg_mean_absolute_error  test_neg_mean_squared_error  \
# 0                     -24.236866                 -1188.753068
# 1                     -24.479065                 -1026.096934
# 2                     -25.173979                  -711.337007
# 3                     -25.956145                  -966.065709
# 4                     -24.089167                 -1257.771946
#
#    train_neg_mean_squared_error  test_neg_median_absolute_error  \
# 0                   -863.297481                      -28.399056
# 1                   -862.997258                      -23.823609
# 2                   -917.197450                      -18.716697
# 3                   -924.263507                      -20.206496
# 4                   -855.891828                      -28.889051
#
#    train_neg_median_absolute_error
# 0                       -21.690592
# 1                       -22.157002
# 2                       -23.076240
# 3                       -24.266939
# 4                       -22.231524

# %%
data_model_report=pd.DataFrame()
data_model_report=data_model_report.append([pd_scores_lasso,pd_scores_ridge,pd_scores_net_reg,pd_scores_sgdr,pd_scores_laso],ignore_index=True)
data_model_report.insert(1, " SearchStrategy ",'RandomizedSearchCV')
# Out:
#        ModelName     SearchStrategy    fit_time  score_time  \
# 0        Lasso_1  RandomizedSearchCV   6.098969    0.004492
# 1        Lasso_2  RandomizedSearchCV   7.544734    0.003992
# 2        Lasso_3  RandomizedSearchCV   6.200274    0.004492
# 3        Lasso_4  RandomizedSearchCV   7.329637    0.003993
# 4        Lasso_5  RandomizedSearchCV   6.353981    0.003994
# 5        Ridge_1  RandomizedSearchCV   2.664961    0.003990
# 6        Ridge_2  RandomizedSearchCV   2.613557    0.005489
# 7        Ridge_3  RandomizedSearchCV   2.631525    0.003992
# 8        Ridge_4  RandomizedSearchCV   2.614553    0.004493
# 9        Ridge_5  RandomizedSearchCV   2.581115    0.003993
# 10  ElasticNet_1  RandomizedSearchCV  11.747275    0.003992
# 11  ElasticNet_2  RandomizedSearchCV  10.070449    0.003991
# 12  ElasticNet_3  RandomizedSearchCV   9.890287    0.003992
# 13  ElasticNet_4  RandomizedSearchCV  12.013764    0.004493
# 14  ElasticNet_5  RandomizedSearchCV  10.210176    0.004493
# 15         SGD_1  RandomizedSearchCV   4.681140    0.002995
# 16         SGD_2  RandomizedSearchCV   5.140270    0.002496
# 17         SGD_3  RandomizedSearchCV   4.514457    0.001997
# 18         SGD_4  RandomizedSearchCV   4.652191    0.002496
# 19         SGD_5  RandomizedSearchCV   4.596300    0.001997
# 20   LassoLars_1  RandomizedSearchCV   2.406444    0.001996
# 21   LassoLars_2  RandomizedSearchCV   2.915481    0.001996
# 22   LassoLars_3  RandomizedSearchCV   2.510747    0.001996
# 23   LassoLars_4  RandomizedSearchCV   2.782732    0.002495
# 24   LassoLars_5  RandomizedSearchCV   2.530709    0.001996
#
#     test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                     -22.492861                     -26.542915
# 1                     -28.110288                     -25.292629
# 2                     -31.142568                     -24.295932
# 3                     -23.697818                     -25.206253
# 4                     -30.422749                     -24.399795
# 5                     -22.521895                     -25.829638
# 6                     -25.614895                     -24.915519
# 7                     -27.867464                     -24.524450
# 8                     -25.225309                     -24.615388
# 9                     -32.629801                     -23.131360
# 10                    -27.747970                     -24.978662
# 11                    -28.585588                     -24.904533
# 12                    -27.986716                     -25.203920
# 13                    -23.783251                     -25.645028
# 14                    -26.775535                     -25.485469
# 15                    -27.995860                     -27.420635
# 16                    -24.665230                     -24.345003
# 17                    -28.239823                     -29.015965
# 18                    -30.074858                     -23.709845
# 19                    -29.554113                     -23.856161
# 20                    -30.425442                     -24.236866
# 21                    -25.804088                     -24.479065
# 22                    -21.556174                     -25.173979
# 23                    -24.762187                     -25.956145
# 24                    -29.758421                     -24.089167
#
#     test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                   -804.591877                   -985.898650
# 1                  -1004.984452                   -947.172683
# 2                  -1339.784033                   -861.365320
# 3                   -900.301867                   -917.430209
# 4                  -1286.935592                   -872.723226
# 5                   -834.883272                   -946.911462
# 6                  -1046.513942                   -896.880794
# 7                  -1039.556331                   -897.629016
# 8                  -1006.130841                   -889.932368
# 9                  -1399.757328                   -810.892142
# 10                 -1057.269636                   -920.780164
# 11                 -1104.074295                   -923.819535
# 12                 -1148.039517                   -903.153271
# 13                  -857.987641                   -967.559262
# 14                 -1074.049728                   -924.407517
# 15                 -1201.517392                  -1158.426264
# 16                  -900.216613                   -870.769352
# 17                 -1228.611385                  -1310.890711
# 18                 -1383.237522                   -889.652790
# 19                 -1238.099548                   -816.156645
# 20                 -1188.753068                   -863.297481
# 21                 -1026.096934                   -862.997258
# 22                  -711.337007                   -917.197450
# 23                  -966.065709                   -924.263507
# 24                 -1257.771946                   -855.891828
#
#     test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                       -19.035597                       -23.695251
# 1                       -27.361920                       -22.776798
# 2                       -28.577077                       -21.748190
# 3                       -18.798960                       -23.810124
# 4                       -28.128453                       -20.829830
# 5                       -19.181058                       -22.094490
# 6                       -23.344430                       -23.288056
# 7                       -28.911643                       -20.736889
# 8                       -17.366068                       -22.186764
# 9                       -32.479047                       -20.128217
# 10                      -26.505246                       -22.293134
# 11                      -25.467898                       -21.977245
# 12                      -25.844953                       -21.816909
# 13                      -22.509531                       -22.215897
# 14                      -22.997109                       -22.000744
# 15                      -22.465961                       -23.648975
# 16                      -24.937104                       -20.484908
# 17                      -21.859992                       -25.033691
# 18                      -26.784360                       -20.199998
# 19                      -25.252975                       -21.349745
# 20                      -28.399056                       -21.690592
# 21                      -23.823609                       -22.157002
# 22                      -18.716697                       -23.076240
# 23                      -20.206496                       -24.266939
# 24                      -28.889051                       -22.231524

# %% [markdown]
# # Generarea raportului

# %%
    data_model_report['test_neg_mean_absolute_error'] = -data_model_report[['test_neg_mean_absolute_error']]
    data_model_report[['train_neg_mean_absolute_error']] = -data_model_report[['train_neg_mean_absolute_error']]
    data_model_report[['test_neg_mean_squared_error']] = -data_model_report[['test_neg_mean_squared_error']]
    data_model_report[['train_neg_mean_squared_error']] = -data_model_report[['train_neg_mean_squared_error']]
    data_model_report[['test_neg_median_absolute_error']] = -data_model_report[['test_neg_median_absolute_error']]
    data_model_report[['train_neg_median_absolute_error']] = -data_model_report[['train_neg_median_absolute_error']]
    
    data_model_report.rename(columns={'test_neg_mean_absolute_error': 'test_mean_absolute_error',
                          'train_neg_mean_absolute_error':  'train_mean_absolute_error',
                          'test_neg_mean_squared_error':    'test_mean_squared_error',
                          'train_neg_mean_squared_error':   'train_mean_squared_error',
                          'test_neg_median_absolute_error': 'test_median_absolute_error', 
                          'train_neg_median_absolute_error':'train_median_absolute_error'}, inplace=True)

# %%
def highlight(s):
    is_max = s == s.max()
    is_min = s == s.min()
    styles = []
    for i in range(0, len(is_max)):
        if is_max[i]:
            styles.append('background-color: red')
        elif is_min[i]:
            styles.append('background-color: green')
        else:
            styles.append('')
    return styles

data_model_report_styled =data_model_report.style.apply(highlight, subset=['test_mean_absolute_error','train_mean_absolute_error','test_mean_squared_error','train_mean_squared_error','test_median_absolute_error','train_median_absolute_error'])

display(data_model_report_styled)
# Out:
# <style  type="text/css" >
#     #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row8_col8 {
#             background-color:  green;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row9_col4 {
#             background-color:  red;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row9_col5 {
#             background-color:  green;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row9_col6 {
#             background-color:  red;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row9_col7 {
#             background-color:  green;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row9_col8 {
#             background-color:  red;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row9_col9 {
#             background-color:  green;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row17_col5 {
#             background-color:  red;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row17_col7 {
#             background-color:  red;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row17_col9 {
#             background-color:  red;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row22_col4 {
#             background-color:  green;
#         }    #T_86b61d26_96cd_11ea_85f4_50465de9c7f9row22_col6 {
#             background-color:  green;
#         }</style><table id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ModelName</th>        <th class="col_heading level0 col1" > SearchStrategy </th>        <th class="col_heading level0 col2" >fit_time</th>        <th class="col_heading level0 col3" >score_time</th>        <th class="col_heading level0 col4" >test_mean_absolute_error</th>        <th class="col_heading level0 col5" >train_mean_absolute_error</th>        <th class="col_heading level0 col6" >test_mean_squared_error</th>        <th class="col_heading level0 col7" >train_mean_squared_error</th>        <th class="col_heading level0 col8" >test_median_absolute_error</th>        <th class="col_heading level0 col9" >train_median_absolute_error</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col0" class="data row0 col0" >Lasso_1</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col1" class="data row0 col1" >RandomizedSearchCV</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col2" class="data row0 col2" >6.098969</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col3" class="data row0 col3" >0.004492</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col4" class="data row0 col4" >22.492861</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col5" class="data row0 col5" >26.542915</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col6" class="data row0 col6" >804.591877</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col7" class="data row0 col7" >985.898650</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col8" class="data row0 col8" >19.035597</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row0_col9" class="data row0 col9" >23.695251</td>
#             </tr>
#             <tr>
#                         <th id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col0" class="data row1 col0" >Lasso_2</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col1" class="data row1 col1" >RandomizedSearchCV</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col2" class="data row1 col2" >7.544734</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col3" class="data row1 col3" >0.003992</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col4" class="data row1 col4" >28.110288</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col5" class="data row1 col5" >25.292629</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col6" class="data row1 col6" >1004.984452</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col7" class="data row1 col7" >947.172683</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col8" class="data row1 col8" >27.361920</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row1_col9" class="data row1 col9" >22.776798</td>
#             </tr>
#             <tr>
#                         <th id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col0" class="data row2 col0" >Lasso_3</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col1" class="data row2 col1" >RandomizedSearchCV</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col2" class="data row2 col2" >6.200274</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col3" class="data row2 col3" >0.004492</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col4" class="data row2 col4" >31.142568</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col5" class="data row2 col5" >24.295932</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col6" class="data row2 col6" >1339.784033</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col7" class="data row2 col7" >861.365320</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col8" class="data row2 col8" >28.577077</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row2_col9" class="data row2 col9" >21.748190</td>
#             </tr>
#             <tr>
#                         <th id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col0" class="data row3 col0" >Lasso_4</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col1" class="data row3 col1" >RandomizedSearchCV</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col2" class="data row3 col2" >7.329637</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col3" class="data row3 col3" >0.003993</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col4" class="data row3 col4" >23.697818</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col5" class="data row3 col5" >25.206253</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col6" class="data row3 col6" >900.301867</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col7" class="data row3 col7" >917.430209</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col8" class="data row3 col8" >18.798960</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row3_col9" class="data row3 col9" >23.810124</td>
#             </tr>
#             <tr>
#                         <th id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row4_col0" class="data row4 col0" >Lasso_5</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row4_col1" class="data row4 col1" >RandomizedSearchCV</td>
#                         <td id="T_86b61d26_96cd_11ea_85f4_50465de9c7f9row
