# %% [markdown]
# # Modele de regresie: CPU Computer Hardware
#
# Sîrbu Matei Dan, _grupa 10LF383_

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# %%
header = ['Vendor Name', 'Model Name', 'MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX', 'PRP', 'ERP']
data_cpu_raw = pd.read_csv("./Datasets/Computer Hardware/machine.data", names=header)
display(HTML('<i>CPU Computer Hardware dataset overview:</i>'))
display(data_cpu_raw)
# Out:
# <i>CPU Computer Hardware dataset overview:</i>
#     Vendor Name     Model Name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ..   ...
# 204   37
# 205   50
# 206   41
# 207   47
# 208   25
#
# [209 rows x 10 columns]

# %%
data_cpu = data_cpu_raw[['MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX', 'PRP']]
data_cpu = data_cpu.astype(int)
display(HTML('<i>Dataset to be analyzed:</i>'))
display(data_cpu)
# Out:
# <i>Dataset to be analyzed:</i>
#      MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP
# 0     125   256   6000   256     16    128  198
# 1      29  8000  32000    32      8     32  269
# 2      29  8000  32000    32      8     32  220
# 3      29  8000  32000    32      8     32  172
# 4      29  8000  16000    32      8     16  132
# ..    ...   ...    ...   ...    ...    ...  ...
# 204   124  1000   8000     0      1      8   42
# 205    98  1000   8000    32      2      8   46
# 206   125  2000   8000     0      2     14   52
# 207   480   512   8000    32      0      0   67
# 208   480  1000   4000     0      0      0   45
#
# [209 rows x 7 columns]

# %%
import sklearn
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.linear_model import Lasso, BayesianRidge, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import MinMaxScaler

X = data_cpu[['MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX']].to_numpy()
y = data_cpu[['PRP']].to_numpy().ravel()
score_tables = []

# %%
param_candidates = {'alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float) } 

param_search = RandomizedSearchCV(estimator=Lasso(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3), n_iter=100)
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_1 = pd.DataFrame({'Model_name': 'Lasso', 'Fold': np.arange(1, 6), 'Search_strategy': 'RandomizedSearchCV'})
score_table_1 = pd.concat([score_table_1,pd.DataFrame(scores)], axis=1)
display(score_table_1)
score_tables.append(score_table_1)
# Out:
#   Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0      Lasso     1  RandomizedSearchCV  0.292598    0.001208
# 1      Lasso     2  RandomizedSearchCV  0.268929    0.000549
# 2      Lasso     3  RandomizedSearchCV  0.253522    0.000546
# 3      Lasso     4  RandomizedSearchCV  0.251216    0.000553
# 4      Lasso     5  RandomizedSearchCV  0.252699    0.000560
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -61.304661                     -33.542528
# 1                    -31.934621                     -40.921976
# 2                    -27.965143                     -42.677278
# 3                    -35.272056                     -38.429216
# 4                    -60.277228                     -27.861359
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -7123.301757                  -2659.100585
# 1                 -2305.983487                  -3845.283963
# 2                 -1495.421450                  -4046.452768
# 3                 -2319.323288                  -3823.115970
# 4                -18644.538361                  -1844.738314
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -42.570747                       -24.181218
# 1                      -22.403702                       -30.681254
# 2                      -22.038221                       -33.221794
# 3                      -23.842410                       -23.644019
# 4                      -24.166820                       -16.210339

# %%
param_candidates = {'alpha_1': np.linspace(start=1e-6, stop=1, num=10000, dtype=float), 'alpha_2': np.linspace(start=1e-6, stop=1, num=10000, dtype=float)} 

param_search = RandomizedSearchCV(estimator=BayesianRidge(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_2 = pd.DataFrame({'Model_name': 'BayesianRidge', 'Fold': np.arange(1, 6), 'Search_strategy': 'RandomizedSearchCV'})
score_table_2 = pd.concat([score_table_2,pd.DataFrame(scores)], axis=1)
display(score_table_2)
score_tables.append(score_table_2)
# Out:
#       Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0  BayesianRidge     1  RandomizedSearchCV  0.083732    0.000622
# 1  BayesianRidge     2  RandomizedSearchCV  0.043363    0.000696
# 2  BayesianRidge     3  RandomizedSearchCV  0.046825    0.000576
# 3  BayesianRidge     4  RandomizedSearchCV  0.041856    0.000625
# 4  BayesianRidge     5  RandomizedSearchCV  0.045548    0.000771
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -60.351027                     -33.600880
# 1                    -31.430214                     -40.787084
# 2                    -27.283274                     -42.663372
# 3                    -35.311584                     -38.312350
# 4                    -56.450443                     -28.222315
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -6964.290748                  -2674.779209
# 1                 -2061.482395                  -3864.371320
# 2                 -1411.817179                  -4070.810701
# 3                 -2215.938850                  -3842.745187
# 4                -17892.903600                  -1952.947497
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -42.340440                       -23.932244
# 1                      -23.323312                       -29.653194
# 2                      -22.106036                       -33.431901
# 3                      -26.148412                       -23.493802
# 4                      -19.799159                       -17.390982

# %%
param_candidates = {'C': [0.001, 0.01, 0.1, 1], 'epsilon': np.linspace(start=1e-6, stop=1, num=10000, dtype=float)} 

param_search = RandomizedSearchCV(estimator=SVR(max_iter=1000), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_3 = pd.DataFrame({'Model_name': 'SVR', 'Fold': np.arange(1, 6), 'Search_strategy': 'RandomizedSearchCV'})
score_table_3 = pd.concat([score_table_3,pd.DataFrame(scores)], axis=1)
display(score_table_3)
score_tables.append(score_table_3)
# Out:
#   Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0        SVR     1  RandomizedSearchCV  0.046386    0.000748
# 1        SVR     2  RandomizedSearchCV  0.041643    0.000709
# 2        SVR     3  RandomizedSearchCV  0.041187    0.000705
# 3        SVR     4  RandomizedSearchCV  0.041455    0.000705
# 4        SVR     5  RandomizedSearchCV  0.041009    0.000688
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                   -107.440941                     -57.206267
# 1                    -24.711845                     -75.967345
# 2                    -61.254642                     -80.899617
# 3                    -61.110636                     -68.904558
# 4                    -98.832994                     -60.323948
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                -49463.265523                 -19798.745596
# 1                 -1589.055698                 -30288.534327
# 2                -11984.889351                 -32465.336972
# 3                -14297.941479                 -28519.001942
# 4                -55025.223835                 -18847.895550
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -27.258434                       -18.220664
# 1                      -16.091488                       -21.891159
# 2                      -28.526068                       -25.805570
# 3                      -20.728564                       -19.247339
# 4                      -22.358735                       -19.084554

# %%
param_candidates = {'alpha': np.linspace(start=1e-6, stop=1, num=10000, dtype=float), 'l1_ratio': np.linspace(start=1e-6, stop=1, num=10000, dtype=float)} 

param_search = RandomizedSearchCV(estimator=ElasticNet(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_4 = pd.DataFrame({'Model_name': 'ElasticNet', 'Fold': np.arange(1, 6), 'Search_strategy': 'RandomizedSearchCV'})
score_table_4 = pd.concat([score_table_4,pd.DataFrame(scores)], axis=1)
display(score_table_4)
score_tables.append(score_table_4)
# Out:
#    Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0  ElasticNet     1  RandomizedSearchCV  0.032785    0.000559
# 1  ElasticNet     2  RandomizedSearchCV  0.029563    0.000669
# 2  ElasticNet     3  RandomizedSearchCV  0.028030    0.000551
# 3  ElasticNet     4  RandomizedSearchCV  0.027928    0.000548
# 4  ElasticNet     5  RandomizedSearchCV  0.027902    0.000559
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -61.298248                     -33.544207
# 1                    -31.934193                     -40.924946
# 2                    -27.975239                     -42.679003
# 3                    -35.285309                     -38.431147
# 4                    -58.686494                     -27.848728
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -7122.543061                  -2659.099053
# 1                 -2304.342996                  -3845.272006
# 2                 -1496.539291                  -4046.444210
# 3                 -2321.137470                  -3823.090942
# 4                -18388.328708                  -1845.954240
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -42.567671                       -24.192780
# 1                      -22.413000                       -30.677393
# 2                      -22.048111                       -33.224472
# 3                      -23.868144                       -23.669410
# 4                      -23.477137                       -16.393197

# %%
param_candidates = {'criterion': ['mse', 'friedman_mse', 'mae'], 'max_depth': np.linspace(start=1, stop=10, num=10, dtype=int)} 

param_search = RandomizedSearchCV(estimator=DecisionTreeRegressor(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_5 = pd.DataFrame({'Model_name': 'DecisionTreeRegressor', 'Fold': np.arange(1, 6), 'Search_strategy': 'RandomizedSearchCV'})
score_table_5 = pd.concat([score_table_5,pd.DataFrame(scores)], axis=1)
display(score_table_5)
score_tables.append(score_table_5)
# Out:
#               Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0  DecisionTreeRegressor     1  RandomizedSearchCV  0.038138    0.000595
# 1  DecisionTreeRegressor     2  RandomizedSearchCV  0.036082    0.000586
# 2  DecisionTreeRegressor     3  RandomizedSearchCV  0.031029    0.000587
# 3  DecisionTreeRegressor     4  RandomizedSearchCV  0.035362    0.000597
# 4  DecisionTreeRegressor     5  RandomizedSearchCV  0.031996    0.000590
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -50.940476                      -2.622754
# 1                    -19.181349                      -4.621158
# 2                    -20.467262                      -6.506977
# 3                    -36.575397                      -4.842382
# 4                    -80.826800                      -7.879578
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -8413.839286                    -63.131737
# 1                 -1197.728948                   -137.576547
# 2                  -964.948537                   -194.877272
# 3                 -2217.198743                   -133.610113
# 4                -33260.464466                   -184.688131
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -20.000000                        -0.000000
# 1                       -9.750000                        -0.333333
# 2                      -11.520833                        -2.333333
# 3                      -26.500000                        -1.000000
# 4                      -20.000000                        -4.312500

# %% [markdown]
# # Generarea raportului

# %%
for table in score_tables:
    table[['test_neg_mean_absolute_error']] = -table[['test_neg_mean_absolute_error']]
    table[['train_neg_mean_absolute_error']] = -table[['train_neg_mean_absolute_error']]
    table[['test_neg_mean_squared_error']] = -table[['test_neg_mean_squared_error']]
    table[['train_neg_mean_squared_error']] = -table[['train_neg_mean_squared_error']]
    table[['test_neg_median_absolute_error']] = -table[['test_neg_median_absolute_error']]
    table[['train_neg_median_absolute_error']] = -table[['train_neg_median_absolute_error']]
    table.rename(columns={'test_neg_mean_absolute_error':   'test_mean_absolute_error',
                          'train_neg_mean_absolute_error':  'train_mean_absolute_error',
                          'test_neg_mean_squared_error':    'test_mean_squared_error',
                          'train_neg_mean_squared_error':   'train_mean_squared_error',
                          'test_neg_median_absolute_error': 'test_median_absolute_error', 
                          'train_neg_median_absolute_error':'train_median_absolute_error'}, inplace=True)

# %%
def highlight(s):
    is_max = s == s.max()
    is_min = s == s.min()
    styles = []
    for i in range(0, len(is_max)):
        if is_max[i]:
            styles.append('background-color: red')
        elif is_min[i]:
            styles.append('background-color: green')
        else:
            styles.append('')
    return styles

all_scores = pd.concat(score_tables, ignore_index=True)
all_scores_styled = all_scores.style.apply(highlight, subset=['test_mean_absolute_error','train_mean_absolute_error','test_mean_squared_error','train_mean_squared_error','test_median_absolute_error','train_median_absolute_error'])
display(all_scores_styled)
# Out:
# <style  type="text/css" >
#     #T_193e45b8_9682_11ea_849d_acde48001122row0_col9 {
#             background-color:  red;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row7_col10 {
#             background-color:  red;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row10_col5 {
#             background-color:  red;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row12_col6 {
#             background-color:  red;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row12_col8 {
#             background-color:  red;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row14_col7 {
#             background-color:  red;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row20_col6 {
#             background-color:  green;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row20_col8 {
#             background-color:  green;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row20_col10 {
#             background-color:  green;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row21_col5 {
#             background-color:  green;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row21_col9 {
#             background-color:  green;
#         }    #T_193e45b8_9682_11ea_849d_acde48001122row22_col7 {
#             background-color:  green;
#         }</style><table id="T_193e45b8_9682_11ea_849d_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_name</th>        <th class="col_heading level0 col1" >Fold</th>        <th class="col_heading level0 col2" >Search_strategy</th>        <th class="col_heading level0 col3" >fit_time</th>        <th class="col_heading level0 col4" >score_time</th>        <th class="col_heading level0 col5" >test_mean_absolute_error</th>        <th class="col_heading level0 col6" >train_mean_absolute_error</th>        <th class="col_heading level0 col7" >test_mean_squared_error</th>        <th class="col_heading level0 col8" >train_mean_squared_error</th>        <th class="col_heading level0 col9" >test_median_absolute_error</th>        <th class="col_heading level0 col10" >train_median_absolute_error</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_193e45b8_9682_11ea_849d_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col0" class="data row0 col0" >Lasso</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col2" class="data row0 col2" >RandomizedSearchCV</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col3" class="data row0 col3" >0.292598</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col4" class="data row0 col4" >0.001208</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col5" class="data row0 col5" >61.304661</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col6" class="data row0 col6" >33.542528</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col7" class="data row0 col7" >7123.301757</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col8" class="data row0 col8" >2659.100585</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col9" class="data row0 col9" >42.570747</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row0_col10" class="data row0 col10" >24.181218</td>
#             </tr>
#             <tr>
#                         <th id="T_193e45b8_9682_11ea_849d_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col0" class="data row1 col0" >Lasso</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col2" class="data row1 col2" >RandomizedSearchCV</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col3" class="data row1 col3" >0.268929</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col4" class="data row1 col4" >0.000549</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col5" class="data row1 col5" >31.934621</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col6" class="data row1 col6" >40.921976</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col7" class="data row1 col7" >2305.983487</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col8" class="data row1 col8" >3845.283963</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col9" class="data row1 col9" >22.403702</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row1_col10" class="data row1 col10" >30.681254</td>
#             </tr>
#             <tr>
#                         <th id="T_193e45b8_9682_11ea_849d_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col0" class="data row2 col0" >Lasso</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col2" class="data row2 col2" >RandomizedSearchCV</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col3" class="data row2 col3" >0.253522</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col4" class="data row2 col4" >0.000546</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col5" class="data row2 col5" >27.965143</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col6" class="data row2 col6" >42.677278</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col7" class="data row2 col7" >1495.421450</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col8" class="data row2 col8" >4046.452768</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col9" class="data row2 col9" >22.038221</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row2_col10" class="data row2 col10" >33.221794</td>
#             </tr>
#             <tr>
#                         <th id="T_193e45b8_9682_11ea_849d_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col0" class="data row3 col0" >Lasso</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col1" class="data row3 col1" >4</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col2" class="data row3 col2" >RandomizedSearchCV</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col3" class="data row3 col3" >0.251216</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col4" class="data row3 col4" >0.000553</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col5" class="data row3 col5" >35.272056</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col6" class="data row3 col6" >38.429216</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col7" class="data row3 col7" >2319.323288</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col8" class="data row3 col8" >3823.115970</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col9" class="data row3 col9" >23.842410</td>
#                         <td id="T_193e45b8_9682_11ea_849d_acde48001122row3_col10" cl

# %% [markdown]
# # Exportarea raportului

# %%
html_str = """
<h1><u>CPU computer hardware</u></h1>
"""
html_str = html_str + (all_scores_styled.render())
html_file = open("./Reports/cpu_reg_report.html", "w")
html_file.write(html_str)
html_file.close()
