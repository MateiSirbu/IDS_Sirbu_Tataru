# %% [markdown]
# # Modele de regresie: CPU Computer Hardware
#
# Sîrbu Matei Dan, _grupa 10LF383_

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# %%
header = ['Vendor Name', 'Model Name', 'MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX', 'PRP', 'ERP']
data_cpu_raw = pd.read_csv("./Datasets/Computer Hardware/machine.data", names=header)
display(HTML('<i>CPU Computer Hardware dataset overview:</i>'))
display(data_cpu_raw)
# Out:
# <i>CPU Computer Hardware dataset overview:</i>
#     Vendor Name     Model Name  MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP  \
# 0       adviser          32/60   125   256   6000   256     16    128  198
# 1        amdahl         470v/7    29  8000  32000    32      8     32  269
# 2        amdahl        470v/7a    29  8000  32000    32      8     32  220
# 3        amdahl        470v/7b    29  8000  32000    32      8     32  172
# 4        amdahl        470v/7c    29  8000  16000    32      8     16  132
# ..          ...            ...   ...   ...    ...   ...    ...    ...  ...
# 204      sperry           80/8   124  1000   8000     0      1      8   42
# 205      sperry  90/80-model-3    98  1000   8000    32      2      8   46
# 206      sratus             32   125  2000   8000     0      2     14   52
# 207        wang         vs-100   480   512   8000    32      0      0   67
# 208        wang          vs-90   480  1000   4000     0      0      0   45
#
#      ERP
# 0    199
# 1    253
# 2    253
# 3    253
# 4    132
# ..   ...
# 204   37
# 205   50
# 206   41
# 207   47
# 208   25
#
# [209 rows x 10 columns]

# %%
data_cpu = data_cpu_raw[['MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX', 'PRP']]
data_cpu = data_cpu.astype(int)
display(HTML('<i>Dataset to be analyzed:</i>'))
display(data_cpu)
# Out:
# <i>Dataset to be analyzed:</i>
#      MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PRP
# 0     125   256   6000   256     16    128  198
# 1      29  8000  32000    32      8     32  269
# 2      29  8000  32000    32      8     32  220
# 3      29  8000  32000    32      8     32  172
# 4      29  8000  16000    32      8     16  132
# ..    ...   ...    ...   ...    ...    ...  ...
# 204   124  1000   8000     0      1      8   42
# 205    98  1000   8000    32      2      8   46
# 206   125  2000   8000     0      2     14   52
# 207   480   512   8000    32      0      0   67
# 208   480  1000   4000     0      0      0   45
#
# [209 rows x 7 columns]

# %%
import sklearn
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV, cross_validate
from sklearn.linear_model import Lasso, BayesianRidge, ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import MinMaxScaler

X = data_cpu[['MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX']].to_numpy()
y = data_cpu[['PRP']].to_numpy().ravel()
score_tables = []

# %%
param_candidates = {'alpha': np.linspace(start=1e-5, stop=1, num=10000, dtype=float) } 

param_search = RandomizedSearchCV(estimator=Lasso(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3), n_iter=100)
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_1 = pd.DataFrame({'Model_name': np.repeat('Lasso', 5), 'Fold': np.arange(1, 6), 'Search_strategy': np.repeat('RandomizedSearchCV', 5)})
score_table_1 = pd.concat([score_table_1,pd.DataFrame(scores)], axis=1)
display(score_table_1)
score_tables.append(score_table_1)
# Out:
#   Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0      Lasso     1  RandomizedSearchCV  0.271561    0.000601
# 1      Lasso     2  RandomizedSearchCV  0.262462    0.000552
# 2      Lasso     3  RandomizedSearchCV  0.252442    0.000578
# 3      Lasso     4  RandomizedSearchCV  0.250499    0.000551
# 4      Lasso     5  RandomizedSearchCV  0.255944    0.000547
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -61.305867                     -33.542890
# 1                    -31.934554                     -40.921927
# 2                    -27.965063                     -42.677265
# 3                    -35.272646                     -38.429436
# 4                    -60.279010                     -27.861408
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -7123.602957                  -2659.097020
# 1                 -2305.962094                  -3845.284247
# 2                 -1495.411138                  -4046.452920
# 3                 -2319.461841                  -3823.113818
# 4                -18644.910224                  -1844.738310
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -42.570775                       -24.179804
# 1                      -22.403228                       -30.681290
# 2                      -22.038143                       -33.221831
# 3                      -23.843033                       -23.645018
# 4                      -24.167595                       -16.210464

# %%
param_candidates = {'alpha_1': np.linspace(start=1e-6, stop=1, num=10000, dtype=float), 'alpha_2': np.linspace(start=1e-6, stop=1, num=10000, dtype=float)} 

param_search = RandomizedSearchCV(estimator=BayesianRidge(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_2 = pd.DataFrame({'Model_name': np.repeat('BayesianRidge', 5), 'Fold': np.arange(1, 6), 'Search_strategy': np.repeat('RandomizedSearchCV', 5)})
score_table_2 = pd.concat([score_table_2,pd.DataFrame(scores)], axis=1)
display(score_table_2)
score_tables.append(score_table_2)
# Out:
#       Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0  BayesianRidge     1  RandomizedSearchCV  0.055011    0.000602
# 1  BayesianRidge     2  RandomizedSearchCV  0.044367    0.000589
# 2  BayesianRidge     3  RandomizedSearchCV  0.046741    0.000701
# 3  BayesianRidge     4  RandomizedSearchCV  0.048407    0.000728
# 4  BayesianRidge     5  RandomizedSearchCV  0.042210    0.000686
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -60.349225                     -33.601253
# 1                    -31.430321                     -40.787111
# 2                    -27.282863                     -42.663295
# 3                    -35.311586                     -38.312349
# 4                    -56.451432                     -28.222265
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -6963.987456                  -2674.849623
# 1                 -2061.550990                  -3864.361418
# 2                 -1411.783889                  -4070.859705
# 3                 -2215.938458                  -3842.745386
# 4                -17893.236336                  -1952.975960
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -42.339617                       -23.937021
# 1                      -23.323074                       -29.653463
# 2                      -22.105047                       -33.431490
# 3                      -26.148431                       -23.493798
# 4                      -19.798522                       -17.390695

# %%
param_candidates = {'C': [0.001, 0.01, 0.1, 1], 'epsilon': np.linspace(start=1e-6, stop=1, num=10000, dtype=float)} 

param_search = RandomizedSearchCV(estimator=SVR(max_iter=1000), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_3 = pd.DataFrame({'Model_name': np.repeat('SVR', 5), 'Fold': np.arange(1, 6), 'Search_strategy': np.repeat('RandomizedSearchCV', 5)})
score_table_3 = pd.concat([score_table_3,pd.DataFrame(scores)], axis=1)
display(score_table_3)
score_tables.append(score_table_3)
# Out:
#   Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0        SVR     1  RandomizedSearchCV  0.045469    0.000712
# 1        SVR     2  RandomizedSearchCV  0.042710    0.000720
# 2        SVR     3  RandomizedSearchCV  0.041527    0.000711
# 3        SVR     4  RandomizedSearchCV  0.041737    0.000709
# 4        SVR     5  RandomizedSearchCV  0.041605    0.000747
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                   -107.344447                     -57.113726
# 1                    -24.798887                     -75.964988
# 2                    -48.862505                     -72.513410
# 3                    -61.072164                     -68.927711
# 4                   -109.671007                     -68.703339
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                -49411.376489                 -19764.736405
# 1                 -1588.354594                 -30257.711682
# 2                 -9264.485153                 -29385.540133
# 3                -14271.456001                 -28486.971122
# 4                -59492.232761                 -21399.464870
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -27.492795                       -18.212323
# 1                      -16.352613                       -21.630033
# 2                      -20.508142                       -22.389687
# 3                      -21.051624                       -19.572271
# 4                      -26.670889                       -24.320282

# %%
param_candidates = {'alpha': np.linspace(start=1e-6, stop=1, num=10000, dtype=float), 'l1_ratio': np.linspace(start=1e-6, stop=1, num=10000, dtype=float)} 

param_search = RandomizedSearchCV(estimator=ElasticNet(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_4 = pd.DataFrame({'Model_name': np.repeat('ElasticNet', 5), 'Fold': np.arange(1, 6), 'Search_strategy': np.repeat('RandomizedSearchCV', 5)})
score_table_4 = pd.concat([score_table_4,pd.DataFrame(scores)], axis=1)
display(score_table_4)
score_tables.append(score_table_4)
# Out:
#    Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0  ElasticNet     1  RandomizedSearchCV  0.033046    0.000586
# 1  ElasticNet     2  RandomizedSearchCV  0.029246    0.000559
# 2  ElasticNet     3  RandomizedSearchCV  0.028997    0.000929
# 3  ElasticNet     4  RandomizedSearchCV  0.028455    0.000548
# 4  ElasticNet     5  RandomizedSearchCV  0.028367    0.000556
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -61.293317                     -33.544796
# 1                    -31.948360                     -40.933474
# 2                    -27.974507                     -42.678875
# 3                    -35.274293                     -38.430011
# 4                    -58.957417                     -27.848123
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -7121.798476                  -2659.102338
# 1                 -2309.774782                  -3845.240286
# 2                 -1496.464212                  -4046.444434
# 3                 -2319.825072                  -3823.108306
# 4                -18424.263825                  -1845.576245
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -42.565863                       -24.200876
# 1                      -22.506308                       -30.672267
# 2                      -22.047392                       -33.224029
# 3                      -23.845133                       -23.648770
# 4                      -23.595672                       -16.455677

# %%
param_candidates = {'criterion': ['mse', 'friedman_mse', 'mae'], 'max_depth': np.linspace(start=1, stop=10, num=10, dtype=int)} 

param_search = RandomizedSearchCV(estimator=DecisionTreeRegressor(), scoring='neg_mean_squared_error', param_distributions=param_candidates, cv=KFold(3))
scores = cross_validate(param_search, X, y, cv=KFold(5), scoring=['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error'], return_train_score=True)
score_table_5 = pd.DataFrame({'Model_name': np.repeat('DecisionTreeRegressor', 5), 'Fold': np.arange(1, 6), 'Search_strategy': np.repeat('RandomizedSearchCV', 5)})
score_table_5 = pd.concat([score_table_5,pd.DataFrame(scores)], axis=1)
display(score_table_5)
score_tables.append(score_table_5)
# Out:
#               Model_name  Fold     Search_strategy  fit_time  score_time  \
# 0  DecisionTreeRegressor     1  RandomizedSearchCV  0.038723    0.000605
# 1  DecisionTreeRegressor     2  RandomizedSearchCV  0.039210    0.000592
# 2  DecisionTreeRegressor     3  RandomizedSearchCV  0.033809    0.000602
# 3  DecisionTreeRegressor     4  RandomizedSearchCV  0.038073    0.000591
# 4  DecisionTreeRegressor     5  RandomizedSearchCV  0.032823    0.000600
#
#    test_neg_mean_absolute_error  train_neg_mean_absolute_error  \
# 0                    -51.738095                      -6.706587
# 1                    -23.571429                     -15.389222
# 2                    -30.453571                     -15.577763
# 3                    -42.099206                      -4.842382
# 4                    -82.582898                      -7.879578
#
#    test_neg_mean_squared_error  train_neg_mean_squared_error  \
# 0                 -8541.642857                   -206.640719
# 1                 -1623.190476                   -670.850299
# 2                 -2765.247393                   -518.177718
# 3                 -3078.627315                   -133.610113
# 4                -33459.098613                   -184.688131
#
#    test_neg_median_absolute_error  train_neg_median_absolute_error
# 0                      -21.500000                        -2.000000
# 1                      -15.500000                        -7.000000
# 2                      -13.722222                        -9.222222
# 3                      -30.500000                        -1.000000
# 4                      -20.000000                        -4.312500

# %% [markdown]
# # Generarea raportului

# %%
for table in score_tables:
    table[['test_neg_mean_absolute_error']] = -table[['test_neg_mean_absolute_error']]
    table[['train_neg_mean_absolute_error']] = -table[['train_neg_mean_absolute_error']]
    table[['test_neg_mean_squared_error']] = -table[['test_neg_mean_squared_error']]
    table[['train_neg_mean_squared_error']] = -table[['train_neg_mean_squared_error']]
    table[['test_neg_median_absolute_error']] = -table[['test_neg_median_absolute_error']]
    table[['train_neg_median_absolute_error']] = -table[['train_neg_median_absolute_error']]
    table.rename(columns={'test_neg_mean_absolute_error':   'test_mean_absolute_error',
                          'train_neg_mean_absolute_error':  'train_mean_absolute_error',
                          'test_neg_mean_squared_error':    'test_mean_squared_error',
                          'train_neg_mean_squared_error':   'train_mean_squared_error',
                          'test_neg_median_absolute_error': 'test_median_absolute_error', 
                          'train_neg_median_absolute_error':'train_median_absolute_error'}, inplace=True)

# %%
def highlight(s):
    is_max = s == s.max()
    is_min = s == s.min()
    styles = []
    for i in range(0, len(is_max)):
        if is_max[i]:
            styles.append('background-color: red')
        elif is_min[i]:
            styles.append('background-color: green')
        else:
            styles.append('')
    return styles

all_scores = pd.concat(score_tables, ignore_index=True)
all_scores_styled = all_scores.style.apply(highlight, subset=['test_mean_absolute_error','train_mean_absolute_error','test_mean_squared_error','train_mean_squared_error','test_median_absolute_error','train_median_absolute_error'])
display(all_scores_styled)
# Out:
# <style  type="text/css" >
#     #T_67e80468_951c_11ea_9e9c_acde48001122row0_col9 {
#             background-color:  red;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row7_col7 {
#             background-color:  green;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row7_col10 {
#             background-color:  red;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row11_col6 {
#             background-color:  red;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row11_col8 {
#             background-color:  red;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row14_col5 {
#             background-color:  red;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row14_col7 {
#             background-color:  red;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row21_col5 {
#             background-color:  green;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row22_col9 {
#             background-color:  green;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row23_col6 {
#             background-color:  green;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row23_col8 {
#             background-color:  green;
#         }    #T_67e80468_951c_11ea_9e9c_acde48001122row23_col10 {
#             background-color:  green;
#         }</style><table id="T_67e80468_951c_11ea_9e9c_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_name</th>        <th class="col_heading level0 col1" >Fold</th>        <th class="col_heading level0 col2" >Search_strategy</th>        <th class="col_heading level0 col3" >fit_time</th>        <th class="col_heading level0 col4" >score_time</th>        <th class="col_heading level0 col5" >test_mean_absolute_error</th>        <th class="col_heading level0 col6" >train_mean_absolute_error</th>        <th class="col_heading level0 col7" >test_mean_squared_error</th>        <th class="col_heading level0 col8" >train_mean_squared_error</th>        <th class="col_heading level0 col9" >test_median_absolute_error</th>        <th class="col_heading level0 col10" >train_median_absolute_error</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67e80468_951c_11ea_9e9c_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col0" class="data row0 col0" >Lasso</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col2" class="data row0 col2" >RandomizedSearchCV</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col3" class="data row0 col3" >0.271561</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col4" class="data row0 col4" >0.000601</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col5" class="data row0 col5" >61.305867</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col6" class="data row0 col6" >33.542890</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col7" class="data row0 col7" >7123.602957</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col8" class="data row0 col8" >2659.097020</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col9" class="data row0 col9" >42.570775</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row0_col10" class="data row0 col10" >24.179804</td>
#             </tr>
#             <tr>
#                         <th id="T_67e80468_951c_11ea_9e9c_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col0" class="data row1 col0" >Lasso</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col2" class="data row1 col2" >RandomizedSearchCV</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col3" class="data row1 col3" >0.262462</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col4" class="data row1 col4" >0.000552</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col5" class="data row1 col5" >31.934554</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col6" class="data row1 col6" >40.921927</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col7" class="data row1 col7" >2305.962094</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col8" class="data row1 col8" >3845.284247</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col9" class="data row1 col9" >22.403228</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row1_col10" class="data row1 col10" >30.681290</td>
#             </tr>
#             <tr>
#                         <th id="T_67e80468_951c_11ea_9e9c_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col0" class="data row2 col0" >Lasso</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col2" class="data row2 col2" >RandomizedSearchCV</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col3" class="data row2 col3" >0.252442</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col4" class="data row2 col4" >0.000578</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col5" class="data row2 col5" >27.965063</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col6" class="data row2 col6" >42.677265</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col7" class="data row2 col7" >1495.411138</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col8" class="data row2 col8" >4046.452920</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col9" class="data row2 col9" >22.038143</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row2_col10" class="data row2 col10" >33.221831</td>
#             </tr>
#             <tr>
#                         <th id="T_67e80468_951c_11ea_9e9c_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col0" class="data row3 col0" >Lasso</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col1" class="data row3 col1" >4</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col2" class="data row3 col2" >RandomizedSearchCV</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col3" class="data row3 col3" >0.250499</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col4" class="data row3 col4" >0.000551</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col5" class="data row3 col5" >35.272646</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col6" class="data row3 col6" >38.429436</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col7" class="data row3 col7" >2319.461841</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col8" class="data row3 col8" >3823.113818</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col9" class="data row3 col9" >23.843033</td>
#                         <td id="T_67e80468_951c_11ea_9e9c_acde48001122row3_col10" cla

# %% [markdown]
# # Exportarea raportului

# %%
html_str = """
<h1><u>CPU computer hardware</u></h1>
"""
html_str = html_str + (all_scores_styled.render())
html_file = open("./Reports/cpu_reg_report.html", "w")
html_file.write(html_str)
html_file.close()
